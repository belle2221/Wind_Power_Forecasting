# %%
# import packages
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import math
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import GridSearchCV

# for scaling
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the cleaned data file
df1 = pd.read_csv('v2_cleaned_Turbine_data.csv')
df1
# Out:
#                       Unnamed: 0  ActivePower  AmbientTemperatue  \
# 0      2018-01-01 06:20:00+00:00    26.212347          28.696304
# 1      2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2      2018-01-01 06:50:00+00:00    40.889650          28.984758
# 3      2018-01-01 10:40:00+00:00    34.398111          30.282058
# 4      2018-01-01 12:00:00+00:00    29.797653          29.333519
# ...                          ...          ...                ...
# 78676  2020-03-30 23:10:00+00:00    70.044465          27.523741
# 78677  2020-03-30 23:20:00+00:00    40.833474          27.602882
# 78678  2020-03-30 23:30:00+00:00    20.777790          27.560925
# 78679  2020-03-30 23:40:00+00:00    62.091039          27.810472
# 78680  2020-03-30 23:50:00+00:00    68.664425          27.915828
#
#        BearingShaftTemperature  Blade1PitchAngle  Blade2PitchAngle  \
# 0                    42.921070          0.390534          0.885209
# 1                    42.921070          0.390534          0.885209
# 2                    42.921070          0.390534          0.885209
# 3                    42.921070          0.390534          0.885209
# 4                    42.921070          0.390534          0.885209
# ...                        ...               ...               ...
# 78676                45.711129          1.515669          1.950088
# 78677                45.598573          1.702809          2.136732
# 78678                45.462045          1.706214          2.139664
# 78679                45.343827          1.575352          2.009781
# 78680                45.231610          1.499323          1.933124
#
#        Blade3PitchAngle  GearboxBearingTemperature  GearboxOilTemperature  \
# 0              0.885209                  64.843517              57.189826
# 1              0.885209                  64.843517              57.189826
# 2              0.885209                  64.843517              57.189826
# 3              0.885209                  64.843517              57.189826
# 4              0.885209                  64.843517              57.189826
# ...                 ...                        ...                    ...
# 78676          1.950088                  59.821165              55.193793
# 78677          2.136732                  59.142038              54.798545
# 78678          2.139664                  58.439439              54.380456
# 78679          2.009781                  58.205413              54.079014
# 78680          1.933124                  58.581716              54.080505
#
#        GeneratorRPM  GeneratorWinding1Temperature  \
# 0       1123.212640                     65.733543
# 1       1123.212640                     65.733543
# 2       1123.212640                     65.733543
# 3       1123.212640                     65.733543
# 4       1123.212640                     65.733543
# ...             ...                           ...
# 78676   1029.870744                     59.060367
# 78677   1030.160478                     58.452003
# 78678   1030.137822                     58.034071
# 78679   1030.178178                     57.795387
# 78680   1029.834789                     57.694813
#
#        GeneratorWinding2Temperature  HubTemperature  MainBoxTemperature  \
# 0                         64.944908       37.003815           39.500000
# 1                         64.944908       37.003815           39.500000
# 2                         64.944908       37.003815           39.500000
# 3                         64.944908       37.003815           39.500000
# 4                         64.944908       37.003815           39.500000
# ...                             ...             ...                 ...
# 78676                     58.148777       39.008931           36.476562
# 78677                     57.550367       39.006759           36.328125
# 78678                     57.099335       39.003815           36.131944
# 78679                     56.847239       39.003815           36.007805
# 78680                     56.741040       39.003815           35.914062
#
#        NacellePosition  ReactivePower   RotorRPM  TurbineStatus  \
# 0               252.00       3.976499  10.086061            2.0
# 1               255.00      11.091660  10.086061            2.0
# 2               264.75       4.234497  10.086061            2.0
# 3               283.75       5.347792  10.086061            2.0
# 4               274.00       6.022326  10.086061            2.0
# ...                ...            ...        ...            ...
# 78676           178.00      13.775785   9.234004            2.0
# 78677           178.00       8.088928   9.229370            2.0
# 78678           178.00       4.355978   9.236802            2.0
# 78679           190.00      12.018077   9.237374            2.0
# 78680           203.00      14.439669   9.235532            2.0
#
#        WindDirection  WindSpeed
# 0             252.00   3.042750
# 1             255.00   3.424814
# 2             264.75   3.507172
# 3             283.75   3.442212
# 4             274.00   3.031363
# ...              ...        ...
# 78676         178.00   3.533445
# 78677         178.00   3.261231
# 78678         178.00   3.331839
# 78679         190.00   3.284468
# 78680         203.00   3.475205
#
# [78681 rows x 20 columns]

# %%
df1.rename(columns = {'Unnamed: 0':'timestamp'}, inplace = True)
df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
df1['year']   = df1['timestamp'].dt.year
df1['month']  = df1['timestamp'].dt.month
df1['YearMonth'] = df1['timestamp'].apply(lambda x: x.strftime("%Y-%m"))
df1['day']    = df1['timestamp'].dt.day
df1['hour']   = df1['timestamp'].dt.hour
df1['minute'] = df1['timestamp'].dt.minute
df1['YearMonthDay'] = df1['timestamp'].apply(lambda x: x.strftime("%Y-%m-%d"))
df1.set_index('timestamp')
# Out:
#                            ActivePower  AmbientTemperatue  \
# timestamp
# 2018-01-01 06:20:00+00:00    26.212347          28.696304
# 2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2018-01-01 06:50:00+00:00    40.889650          28.984758
# 2018-01-01 10:40:00+00:00    34.398111          30.282058
# 2018-01-01 12:00:00+00:00    29.797653          29.333519
# ...                                ...                ...
# 2020-03-30 23:10:00+00:00    70.044465          27.523741
# 2020-03-30 23:20:00+00:00    40.833474          27.602882
# 2020-03-30 23:30:00+00:00    20.777790          27.560925
# 2020-03-30 23:40:00+00:00    62.091039          27.810472
# 2020-03-30 23:50:00+00:00    68.664425          27.915828
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# timestamp
# 2018-01-01 06:20:00+00:00                42.921070          0.390534
# 2018-01-01 06:40:00+00:00                42.921070          0.390534
# 2018-01-01 06:50:00+00:00                42.921070          0.390534
# 2018-01-01 10:40:00+00:00                42.921070          0.390534
# 2018-01-01 12:00:00+00:00                42.921070          0.390534
# ...                                            ...               ...
# 2020-03-30 23:10:00+00:00                45.711129          1.515669
# 2020-03-30 23:20:00+00:00                45.598573          1.702809
# 2020-03-30 23:30:00+00:00                45.462045          1.706214
# 2020-03-30 23:40:00+00:00                45.343827          1.575352
# 2020-03-30 23:50:00+00:00                45.231610          1.499323
#
#                            Blade2PitchAngle  Blade3PitchAngle  \
# timestamp
# 2018-01-01 06:20:00+00:00          0.885209          0.885209
# 2018-01-01 06:40:00+00:00          0.885209          0.885209
# 2018-01-01 06:50:00+00:00          0.885209          0.885209
# 2018-01-01 10:40:00+00:00          0.885209          0.885209
# 2018-01-01 12:00:00+00:00          0.885209          0.885209
# ...                                     ...               ...
# 2020-03-30 23:10:00+00:00          1.950088          1.950088
# 2020-03-30 23:20:00+00:00          2.136732          2.136732
# 2020-03-30 23:30:00+00:00          2.139664          2.139664
# 2020-03-30 23:40:00+00:00          2.009781          2.009781
# 2020-03-30 23:50:00+00:00          1.933124          1.933124
#
#                            GearboxBearingTemperature  GearboxOilTemperature  \
# timestamp
# 2018-01-01 06:20:00+00:00                  64.843517              57.189826
# 2018-01-01 06:40:00+00:00                  64.843517              57.189826
# 2018-01-01 06:50:00+00:00                  64.843517              57.189826
# 2018-01-01 10:40:00+00:00                  64.843517              57.189826
# 2018-01-01 12:00:00+00:00                  64.843517              57.189826
# ...                                              ...                    ...
# 2020-03-30 23:10:00+00:00                  59.821165              55.193793
# 2020-03-30 23:20:00+00:00                  59.142038              54.798545
# 2020-03-30 23:30:00+00:00                  58.439439              54.380456
# 2020-03-30 23:40:00+00:00                  58.205413              54.079014
# 2020-03-30 23:50:00+00:00                  58.581716              54.080505
#
#                            GeneratorRPM  GeneratorWinding1Temperature  ...  \
# timestamp                                                              ...
# 2018-01-01 06:20:00+00:00   1123.212640                     65.733543  ...
# 2018-01-01 06:40:00+00:00   1123.212640                     65.733543  ...
# 2018-01-01 06:50:00+00:00   1123.212640                     65.733543  ...
# 2018-01-01 10:40:00+00:00   1123.212640                     65.733543  ...
# 2018-01-01 12:00:00+00:00   1123.212640                     65.733543  ...
# ...                                 ...                           ...  ...
# 2020-03-30 23:10:00+00:00   1029.870744                     59.060367  ...
# 2020-03-30 23:20:00+00:00   1030.160478                     58.452003  ...
# 2020-03-30 23:30:00+00:00   1030.137822                     58.034071  ...
# 2020-03-30 23:40:00+00:00   1030.178178                     57.795387  ...
# 2020-03-30 23:50:00+00:00   1029.834789                     57.694813  ...
#
#                            TurbineStatus  WindDirection  WindSpeed  year  \
# timestamp
# 2018-01-01 06:20:00+00:00            2.0         252.00   3.042750  2018
# 2018-01-01 06:40:00+00:00            2.0         255.00   3.424814  2018
# 2018-01-01 06:50:00+00:00            2.0         264.75   3.507172  2018
# 2018-01-01 10:40:00+00:00            2.0         283.75   3.442212  2018
# 2018-01-01 12:00:00+00:00            2.0         274.00   3.031363  2018
# ...                                  ...            ...        ...   ...
# 2020-03-30 23:10:00+00:00            2.0         178.00   3.533445  2020
# 2020-03-30 23:20:00+00:00            2.0         178.00   3.261231  2020
# 2020-03-30 23:30:00+00:00            2.0         178.00   3.331839  2020
# 2020-03-30 23:40:00+00:00            2.0         190.00   3.284468  2020
# 2020-03-30 23:50:00+00:00            2.0         203.00   3.475205  2020
#
#                            month  YearMonth  day  hour  minute  YearMonthDay
# timestamp
# 2018-01-01 06:20:00+00:00      1    2018-01    1     6      20    2018-01-01
# 2018-01-01 06:40:00+00:00      1    2018-01    1     6      40    2018-01-01
# 2018-01-01 06:50:00+00:00      1    2018-01    1     6      50    2018-01-01
# 2018-01-01 10:40:00+00:00      1    2018-01    1    10      40    2018-01-01
# 2018-01-01 12:00:00+00:00      1    2018-01    1    12       0    2018-01-01
# ...                          ...        ...  ...   ...     ...           ...
# 2020-03-30 23:10:00+00:00      3    2020-03   30    23      10    2020-03-30
# 2020-03-30 23:20:00+00:00      3    2020-03   30    23      20    2020-03-30
# 2020-03-30 23:30:00+00:00      3    2020-03   30    23      30    2020-03-30
# 2020-03-30 23:40:00+00:00      3    2020-03   30    23      40    2020-03-30
# 2020-03-30 23:50:00+00:00      3    2020-03   30    23      50    2020-03-30
#
# [78681 rows x 26 columns]

# %%
df_day = df1.groupby(by=['YearMonthDay']).mean()

# %% [markdown]
# ### Separate into X, y

# %%
X_train, X_test, y_train,y_test = df_day[['WindSpeed']][0:718], df_day[['WindSpeed']][718:748], df_day[['ActivePower']][0:718], df_day[['ActivePower']][718:748]
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((718, 1), (30, 1), (718, 1), (30, 1))

# %% [markdown]
# ### Build Model without hyperparameter tuning

# %%
rf = RandomForestRegressor()

# %%
# Fit the model to the training data 
rf.fit(X_train, y_train)

# Make the predictions
pred = rf.predict(X_test)
df_pred = pd.DataFrame(data={'Actuals':y_test['ActivePower'], 'Predictions':pred}, index=y_test.index)
# Out:
# C:\Users\jhh\AppData\Local\Temp/ipykernel_5204/469167559.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)

# %%
df_pred
# Out:
#                  Actuals  Predictions
# YearMonthDay
# 2020-03-01    443.058496   389.982246
# 2020-03-02    390.027361   364.119452
# 2020-03-03    341.133560   301.928819
# 2020-03-04    122.348957   110.272991
# 2020-03-05    676.893151   610.057255
# 2020-03-06    345.379836   325.534434
# 2020-03-07    516.674962   510.697777
# 2020-03-08    629.447133   547.915938
# 2020-03-09    673.519002   598.830879
# 2020-03-10    581.532630   499.910235
# 2020-03-11    466.289248   420.338686
# 2020-03-12    570.315539   504.825076
# 2020-03-13    619.637333   551.371834
# 2020-03-14    800.312824   655.801728
# 2020-03-15    787.305117   735.566742
# 2020-03-16    644.891382   523.059361
# 2020-03-17    857.485779   794.812933
# 2020-03-18    367.360814   396.852754
# 2020-03-19    629.455480   596.237095
# 2020-03-20    485.411496   508.769594
# 2020-03-21    432.529893   471.173600
# 2020-03-22    481.172384   457.844887
# 2020-03-23    552.187880   502.265735
# 2020-03-24    425.815287   428.450646
# 2020-03-25    754.076163   727.510976
# 2020-03-26    732.042233   652.004742
# 2020-03-27    728.896074   714.197063
# 2020-03-28    874.011580   869.252145
# 2020-03-29    840.439852   795.229867
# 2020-03-30    873.498776   816.309244

# %%
r2 = r2_score(df_pred['Actuals'],df_pred['Predictions'])
mae = mean_absolute_error(df_pred['Actuals'],df_pred['Predictions'])
rmse = mean_squared_error(df_pred['Actuals'],df_pred['Predictions'],squared=False)

print('The Coefficient of determination (R-squared) = {:.3f}'.format(r2))
print('The mean absolute error (MAE)                = {:.2f}'.format(mae))
print('The root mean squared error (RMSE)           = {:.2f}'.format(rmse))
# Out:
# The Coefficient of determination (R-squared) = 0.899
# The mean absolute error (MAE)                = 48.34
# The root mean squared error (RMSE)           = 58.33

# %%
# plot
plt.plot(df_pred['Predictions'],label='Prediction')
plt.plot(df_pred['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.xticks(rotation = 90) 
plt.grid()
plt.show()

# %% [markdown]
# ### Hyperparameter Tuning 1

# %%
params_rf = {'max_depth': [5, 50, 500], 
             'min_samples_leaf': [0.1,0.2], 
             'max_features': ['log2', 'sqrt', 'auto'],
             'n_estimators':[50,100,200,300,400,500]}

grid_rf = GridSearchCV(estimator = rf,
                      param_grid = params_rf,
                      scoring = 'r2',
                      verbose = 1,
                        cv = 5,
                      n_jobs =-1)

# %%
grid_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# C:\Users\jhh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:910: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, 50, 500],
#                          'max_features': ['log2', 'sqrt', 'auto'],
#                          'min_samples_leaf': [0.1, 0.2],
#                          'n_estimators': [50, 100, 200, 300, 400, 500]},
#              scoring='r2', verbose=1)

# %%
best_hyperparams = grid_rf.best_params_ 
print('Best hyerparameters:\n', best_hyperparams)
# Out:
# Best hyerparameters:
#  {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 0.1, 'n_estimators': 50}

# %%
y_pred = grid_rf.predict(X_test)

# %%
# Use the best hyperparameters to make predictions on the test set
best_rf = grid_rf.best_estimator_
pred = best_rf.predict(X_test)

df_final = pd.DataFrame(data={'Actuals':y_test['ActivePower'], 'Predictions':pred}, index=y_test.index)

# %%
df_final
# Out:
#                  Actuals  Predictions
# YearMonthDay
# 2020-03-01    443.058496   403.633964
# 2020-03-02    390.027361   392.669386
# 2020-03-03    341.133560   222.604189
# 2020-03-04    122.348957   222.604189
# 2020-03-05    676.893151   564.675817
# 2020-03-06    345.379836   380.242006
# 2020-03-07    516.674962   468.243212
# 2020-03-08    629.447133   555.925661
# 2020-03-09    673.519002   568.906523
# 2020-03-10    581.532630   544.372079
# 2020-03-11    466.289248   406.550545
# 2020-03-12    570.315539   544.372079
# 2020-03-13    619.637333   550.903904
# 2020-03-14    800.312824   763.023265
# 2020-03-15    787.305117   763.023265
# 2020-03-16    644.891382   555.925661
# 2020-03-17    857.485779   763.023265
# 2020-03-18    367.360814   392.669386
# 2020-03-19    629.455480   555.925661
# 2020-03-20    485.411496   535.096977
# 2020-03-21    432.529893   406.550545
# 2020-03-22    481.172384   451.045709
# 2020-03-23    552.187880   544.372079
# 2020-03-24    425.815287   406.550545
# 2020-03-25    754.076163   763.023265
# 2020-03-26    732.042233   763.023265
# 2020-03-27    728.896074   763.023265
# 2020-03-28    874.011580   763.023265
# 2020-03-29    840.439852   763.023265
# 2020-03-30    873.498776   763.023265

# %%
hp_r2 = r2_score(df_final['Actuals'],df_final['Predictions'])
hp_mae = mean_absolute_error(df_final['Actuals'],df_final['Predictions'])
hp_rmse = mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)

print('The Coefficient of determination (R-squared) = {:.3f}'.format(hp_r2))
print('The mean absolute error (MAE)                = {:.2f}'.format(hp_mae))
print('The RMSE error (RMSE)                        = {:.2f}'.format(hp_rmse))
# Out:
# The Coefficient of determination (R-squared) = 0.871
# The mean absolute error (MAE)                = 55.86
# The RMSE error (RMSE)                        = 65.98

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Hyperparameter Tuning 2

# %%
params_rf2 = {'max_depth': [4, 6, 8], 
             'min_samples_leaf': [0.1, 2],
             'max_features': ['sqrt', 'auto'],
             'n_estimators' : [1, 600, 1200]}

grid_rf2 = GridSearchCV(estimator=rf, param_grid=params_rf2, cv=3, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

# %%
grid_rf2.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# C:\Users\jhh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:910: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\jhh\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [4, 6, 8],
#                          'max_features': ['sqrt', 'auto'],
#                          'min_samples_leaf': [0.1, 2],
#                          'n_estimators': [1, 600, 1200]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
best_hyperparams2 = grid_rf2.best_params_ 
print('Best hyerparameters:\n', best_hyperparams2)
# Out:
# Best hyerparameters:
#  {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 600}

# %%
y_pred = grid_rf2.predict(X_test)

# %%
# Use the best hyperparameters to make predictions on the test set
best_rf2 = grid_rf2.best_estimator_
hp2_pred = best_rf2.predict(X_test)

df_final = pd.DataFrame(data={'Actuals':y_test['ActivePower'], 'Predictions':hp2_pred}, index=y_test.index)

# %%
df_final
# Out:
#                  Actuals  Predictions
# YearMonthDay
# 2020-03-01    443.058496   415.793549
# 2020-03-02    390.027361   358.805729
# 2020-03-03    341.133560   307.011977
# 2020-03-04    122.348957   100.385977
# 2020-03-05    676.893151   609.751185
# 2020-03-06    345.379836   334.374369
# 2020-03-07    516.674962   486.397968
# 2020-03-08    629.447133   559.638954
# 2020-03-09    673.519002   610.539017
# 2020-03-10    581.532630   520.371881
# 2020-03-11    466.289248   427.266413
# 2020-03-12    570.315539   520.371881
# 2020-03-13    619.637333   531.696637
# 2020-03-14    800.312824   640.319564
# 2020-03-15    787.305117   758.384125
# 2020-03-16    644.891382   568.944774
# 2020-03-17    857.485779   775.148749
# 2020-03-18    367.360814   358.805729
# 2020-03-19    629.455480   564.279329
# 2020-03-20    485.411496   519.283159
# 2020-03-21    432.529893   426.084169
# 2020-03-22    481.172384   479.221688
# 2020-03-23    552.187880   520.371881
# 2020-03-24    425.815287   426.393458
# 2020-03-25    754.076163   740.048661
# 2020-03-26    732.042233   653.742494
# 2020-03-27    728.896074   640.319564
# 2020-03-28    874.011580   892.029415
# 2020-03-29    840.439852   769.553421
# 2020-03-30    873.498776   770.857793

# %%
hp2_r2 = r2_score(df_final['Actuals'],df_final['Predictions'])
hp2_mae = mean_absolute_error(df_final['Actuals'],df_final['Predictions'])
hp2_rmse = mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)

print('The Coefficient of determination (R-squared) = {:.3f}'.format(hp2_r2))
print('The mean absolute error (MAE)                = {:.2f}'.format(hp2_mae))
print('The RMSE error (RMSE)                        = {:.2f}'.format(hp2_rmse))
# Out:
# The Coefficient of determination (R-squared) = 0.893
# The mean absolute error (MAE)                = 48.73
# The RMSE error (RMSE)                        = 60.22

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Comparison on models

# %%
results_r2 = [round(r2, 2), round(hp_r2, 2), round(hp2_r2, 2)]
results_mae = [round(mae, 2), round(hp_mae, 2), round(hp2_mae, 2)]
results_rmse = [round(rmse,2), round(hp_rmse, 2), round(hp2_rmse, 2)]

print('r2: ', results_r2)
print('mae: ', results_mae)
print('rmse: ', results_rmse)
# Out:
# r2:  [0.9, 0.87, 0.89]
# mae:  [48.7, 55.86, 48.73]
# rmse:  [59.32, 65.98, 60.22]

# %%
labels = ['RF Model','HP1 RF Model','HP2 RF Model']
barWidth = 0.25  # the width of the bars
br1 = np.arange(len(labels))  # the label locations
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

fig, ax = plt.subplots(figsize =(12, 8))
rects1 = ax.bar(br1, results_r2, barWidth, label='R-Squared')
rects2 = ax.bar(br2, results_mae, barWidth, label='MAE')
rects3 = ax.bar(br3, results_rmse, barWidth, label='RMSE')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores', fontweight ='bold', fontsize = 15)
ax.set_title('Evaluation Metrics of Each Model', fontweight ='bold', fontsize = 15)
ax.set_xticks([r + barWidth for r in range(len(labels))], labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

fig.tight_layout()

plt.show()
